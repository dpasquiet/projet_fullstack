# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv("fr-esr-parcoursup_2023.csv", delimiter=';')

# %%
df.head()
# Out:
#    Session  \
# 0     2023
# 1     2023
# 2     2023
# 3     2023
# 4     2023
#
#   Statut de l’établissement de la filière de formation (public, privé…)  \
# 0                                             Public
# 1                                             Public
# 2                                             Public
# 3                                             Public
# 4                                             Public
#
#   Code UAI de l'établissement                         Établissement  \
# 0                    0010001W  Lycée professionnel Alexandre Berard
# 1                    0010014K                    Lycée Edgar Quinet
# 2                    0010016M            Lycée Joseph-Marie Carriat
# 3                    0010016M            Lycée Joseph-Marie Carriat
# 4                    0010059J        Lycée agricole Edouard Herriot
#
#   Code départemental de l’établissement Département de l’établissement  \
# ...

# %%
df.isna().sum()
# Out:
# Session                                                                                                             0
# Statut de l’établissement de la filière de formation (public, privé…)                                               0
# Code UAI de l'établissement                                                                                         0
# Établissement                                                                                                       0
# Code départemental de l’établissement                                                                               0
#                                                                                                                 ...
# Part des terminales générales qui étaient en position de recevoir une proposition en phase principale               0
# Part des terminales technologiques qui étaient en position de recevoir une proposition en phase principale          0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13869 entries, 0 to 13868
# Columns: 118 entries, Session to composante_id_paysage
# dtypes: float64(45), int64(48), object(25)
# memory usage: 12.5+ MB

# %%
df.shape
# Out:
# (13869, 118)

# %%
for col in ['Session', 'Établissement', 'Filière de formation', 'Académie de l’établissement']:
    print(df[col].unique())
    print(f"{col}:count of unique ",df[col].nunique())
# Out:
# [2023]
# Session:count of unique  1
# ['Lycée professionnel Alexandre Berard' 'Lycée Edgar Quinet'
#  'Lycée Joseph-Marie Carriat' ... 'ESME Sudria Bordeaux' 'EPITA Rennes'
#  'EPITA Toulouse']
# Établissement:count of unique  3602
# ['BTS - Production - Fluide, énergie, domotique - option A génie climatique et fluidique'
#  "BTS - Services - Support à l'action managériale"
#  'BTS - Production - Conception des processus de réalisation de produits (1ère année commune)'
#  ...
#  'Licence - Langues étrangères appliquées - Parcours Anglais et mandarin'
#  'Licence - Lettres - Parcours LETTRES ET ARTS' 'DN MADE - Objet']
# Filière de formation:count of unique  3207
# ['Lyon' 'Amiens' 'Clermont-Ferrand' 'Aix-Marseille' 'Nice' 'Grenoble'
#  'Reims' 'Toulouse' 'Montpellier' 'Normandie' 'Poitiers' 'Orléans-Tours'
#  'Limoges' 'Dijon' 'Rennes' 'Bordeaux' 'Besancon' 'Nantes' 'Nancy-Metz'
#  'Lille' 'Strasbourg' 'Paris' 'Créteil' 'Versailles' 'Etranger' 'Corse'
# ...
