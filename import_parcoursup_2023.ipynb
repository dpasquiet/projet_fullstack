# %%
import requests
import pandas as pd

# %%
response = requests.get("https://data.enseignementsup-recherche.gouv.fr/api/explore/v2.1/catalog/datasets/fr-esr-parcoursup_2023/exports")

print("status code:", response, "\n\n")
print("Response data:\n")
response.text
# Out:
# status code: <Response [200]>
#
#
# Response data:
# ...

# %%
# Make the GET request
# https://data.enseignementsup-recherche.gouv.fr/api/explore/v2.1/catalog/datasets/fr-esr-parcoursup_2023/records?limit=20
# https://data.enseignementsup-recherche.gouv.fr/api/explore/v2.1/catalog/datasets/fr-esr-parcoursup_2022/records?limit=20
# https://data.enseignementsup-recherche.gouv.fr/api/explore/v2.1/catalog/datasets/fr-esr-parcoursup_2021/records?limit=20

url_2023 = "https://data.enseignementsup-recherche.gouv.fr/api/explore/v2.1/catalog/datasets/fr-esr-parcoursup_2023/exports"
parcoursup_2023 = requests.get(url = url_2023)

# %%
parcoursup_2023
# Out:
# <Response [200]>

# %%
parcoursup_2023.json()
# Out:
# {'links': [{'rel': 'self',
#    'href': 'https://data.enseignementsup-recherche.gouv.fr/api/explore/v2.1/catalog/datasets/fr-esr-parcoursup_2023/exports'},
#   {'rel': 'csv',
#    'href': 'https://data.enseignementsup-recherche.gouv.fr/api/explore/v2.1/catalog/datasets/fr-esr-parcoursup_2023/exports/csv'},
#   {'rel': 'json',
#    'href': 'https://data.enseignementsup-recherche.gouv.fr/api/explore/v2.1/catalog/datasets/fr-esr-parcoursup_2023/exports/json'},
#   {'rel': 'fgb',
#    'href': 'https://data.enseignementsup-recherche.gouv.fr/api/explore/v2.1/catalog/datasets/fr-esr-parcoursup_2023/exports/fgb'},
#   {'rel': 'geojson',
#    'href': 'https://data.enseignementsup-recherche.gouv.fr/api/explore/v2.1/catalog/datasets/fr-esr-parcoursup_2023/exports/geojson'},
#   {'rel': 'gpx',
#    'href': 'https://data.enseignementsup-recherche.gouv.fr/api/explore/v2.1/catalog/datasets/fr-esr-parcoursup_2023/exports/gpx'},
#   {'rel': 'jsonl',
# ...

# %%
parcoursup_2023.json()['results']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 parcoursup_2023.json()['results']
#
# KeyError: 'results'

# %%
df_2023 = pd.DataFrame(all_results)

# %%
df_2023
# Out:
#    session                      contrat_etab   cod_uai  \
# 0     2023                            Public  0010014K
# 1     2023                            Public  0010016M
# 2     2023                            Public  0010016M
# 3     2023                            Public  0010016M
# 4     2023  Privé sous contrat d'association  0010070W
# 5     2023                            Public  0010819K
# 6     2023                            Public  0011312W
# 7     2023                            Public  0011312W
# 8     2023                            Public  0011312W
# 9     2023                            Public  0011329P
# 10    2023                            Public  0011385A
# 11    2023      Privé enseignement supérieur  0011402U
# 12    2023  Privé sous contrat d'association  0011438H
# 13    2023                            Public  0020014E
# 14    2023                            Public  0020031Y
# 15    2023                            Public  0020048S
# ...

# %%
df_2023.shape
# Out:
# (20, 118)
